# %% [markdown]
# <a href="https://colab.research.google.com/github/developer0793/davis_python_programs/blob/main/Visualizationexample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import colors
import matplotlib.pyplot as plt
#example for bar chart
#data for x axis
x = ['laptop','Mobile','Keyboard','Mouse','Tablet']
#data for y axis
y = [200,400,100,600,400]
#-------------------------------------------------
#bar chart
plt.bar(x,y,color=['red','blue','green','black','blue'])
#label for x-axis
plt.xlabel('Product')
#label for y axis
plt.ylabel('Sales in units')
#-----------------------------------
#title of chart
plt.title('Product Sales(in Unit)')
#-----------------------------------
#Displaying the chart
plt.show()
