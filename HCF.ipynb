# %% [markdown]
# <a href="https://colab.research.google.com/github/developer0793/davis_python_programs/blob/main/HCF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#to find out oput hcf
#input two number
num1 = int(input("Enter first number : "))
num2 = int(input("Enter second number: "))
#----------------------------------------------
if(num2 == 0):
  print("HCF : ",num1)
else:
  while(num2 != 0):
    rem = num1%num2
    num1 = num2
    num2 = rem
  #-----------------------
  print("HCF : ",num1)
# Out:
# Enter first number : 34
# Enter second number: 12
